# %% [markdown]
# # Import libraries

# %%
# !pip install music21

# %%
import music21
from IPython.display import Image, Audio
import os
import json
import numpy as np
import tensorflow as tf
import pprint
import IPython

# %% [markdown]
# # Music21 setup

# %%
def show(music):
  display(Image(str(music.write('lily.png'))))

def play(music):
  filename = music.write('mid')
  wav_filename = os.path.join(os.path.join(filename)[:-4] + ".wav")
  # !fluidsynth -ni font.sf2 $filename -F $wav_filename -r 16000
  display(Audio(wav_filename))

# %%
paths = music21.corpus.getComposer('bach')
paths
# Out:
# [PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv1.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv10.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv101.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv102.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv103.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv104.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv108.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv11.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv110.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv111.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv112.5-sc.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv112.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv113.8.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv114.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv115.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv116.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv117.4.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv119.9.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv12.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv120.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv120.8-a.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv121.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv122.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv123.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv124.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv125.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv126.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv127.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv128.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv13.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv130.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv133.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv135.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv136.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv137.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv139.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv14.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv140.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv144.3.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv144.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv145-a.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv145.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv146.8.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv148.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv149.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv151.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv153.1.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv153.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv153.9.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv154.3.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv154.8.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv155.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv156.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv157.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv158.4.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv159.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv16.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv161.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv162.6-lpz.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv164.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv165.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv166.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv168.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv169.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv17.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv171.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv172.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv174.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv175.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv176.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv177.4.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv177.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv178.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv179.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv18.5-lz.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv18.5-w.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv180.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv183.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv184.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv185.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv187.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv188.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv19.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv190.7-inst.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv190.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv194.12.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv194.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv195.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv197.10.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv197.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv197.7-a.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv2.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv20.11.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv20.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv226.2.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv227.1.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv227.11.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv227.3.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv227.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv229.2.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv24.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv244.10.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv244.15.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv244.17.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv244.25.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv244.29-a.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv244.3.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv244.32.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv244.37.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv244.40.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv244.44.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv244.46.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv244.54.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv244.62.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv245.11.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv245.14.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv245.15.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv245.17.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv245.22.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv245.26.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv245.28.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv245.3.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv245.37.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv245.40.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv245.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.12-2.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.17.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.23-2.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.23-s.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.28.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.33-3.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.35-3.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.35-3c.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.42-4.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.42-s.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.46-5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.53-5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.59-6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.64-6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.64-s.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.9-1.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv248.9-s.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv25.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv250.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv251.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv252.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv253.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv254.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv255.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv256.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv257.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv258.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv259.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv26.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv260.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv261.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv262.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv263.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv264.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv265.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv266.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv267.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv268.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv269.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv27.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv270.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv271.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv272.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv273.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv274.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv275.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv276.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv277.krn'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv277.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv278.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv279.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv28.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv280.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv281.krn'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv281.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv282.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv283.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv284.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv285.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv286.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv287.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv288.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv289.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv29.8.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv290.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv291.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv292.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv293.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv294.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv295.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv296.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv297.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv298.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv299.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv3.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv30.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv300.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv301.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv302.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv303.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv304.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv305.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv306.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv307.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv308.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv309.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv31.9.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv310.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv311.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv312.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv313.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv314.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv315.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv316.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv317.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv318.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv319.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv32.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv320.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv321.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv322.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv323.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv324.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv325.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv326.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv327.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv328.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv329.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv33.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv330.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv331.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv332.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv333.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv334.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv335.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv336.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv337.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv338.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv339.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv340.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv341.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv342.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv343.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv344.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv345.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv346.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv347.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv348.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv349.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv350.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv351.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv352.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv353.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv354.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv355.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv356.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv357.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv358.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv359.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv36.4-2.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv36.8-2.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv360.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv361.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv362.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv363.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv364.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv365.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv366.krn'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv366.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv367.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv368.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv369.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv37.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv370.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv371.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv372.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv373.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv374.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv375.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv376.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv377.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv378.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv379.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv38.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv380.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv381.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv382.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv383.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv384.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv385.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv386.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv387.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv388.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv389.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv39.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv390.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv391.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv392.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv393.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv394.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv395.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv396.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv397.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv398.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv399.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv4.8.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv40.3.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv40.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv40.8.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv400.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv401.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv402.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv403.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv404.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv405.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv406.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv407.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv408.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv409.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv41.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv410.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv411.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv412.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv413.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv414.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv415.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv416.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv417.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv418.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv419.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv42.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv420.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv421.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv422.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv423.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv424.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv425.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv426.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv427.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv428.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv429.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv43.11.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv430.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv431.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv432.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv433.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv434.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv435.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv436.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv437.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv438.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv44.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv45.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv46.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv47.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv48.3.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv48.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv5.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv52.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv55.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv56.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv57.8.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv59.3.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv6.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv60.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv62.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv64.2.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv64.4.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv64.8.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv65.2.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv65.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv66.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv67.4.xml'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv67.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv69.6-a.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv69.6.xml'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv7.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv70.11.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv70.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv72.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv73.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv74.8.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv77.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv78.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv79.3.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv79.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv8.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv80.8.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv81.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv83.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv84.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv846.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv85.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv86.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv87.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv88.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv89.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv9.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv90.5.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv91.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv92.9.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv93.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv94.8.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv95.7.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv96.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv97.9.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/bwv99.6.mxl'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider001.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider002.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider003.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider004.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider005.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider006.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider007.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider008.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider009.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider010.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider011.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider012.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider013.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider014.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider015.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider016.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider017.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider018.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider019.rntxt'),
#  PosixPath('/usr/local/lib/python3.7/dist-packages/music21/corpus/bach/choraleAnalyses/riemenschneider020.rntxt')]

# %%
#us = music21.environment.UserSettings()
#us.create()
#us['lilypondPath'] = 'C:/LilyPond/usr/bin/lilypond.exe'

# %%
#music = music21.corpus.parse('bach/bwv87.7.mxl')
music = music21.corpus.parse(paths[6])
show(music)
play(music)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/music21/lily/translate.py in setupTools(self)
#     189         try:
# --> 190             proc = subprocess.Popen(command, stdout=subprocess.PIPE)
#     191         except OSError: # pragma: no cover
#
# /usr/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# /usr/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1550                             err_msg += ': ' + repr(err_filename)
# -> 1551                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1552                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lilypond': 'lilypond'
#
# During handling of the above exception, another exception occurred:
#
# LilyTranslateException                    Traceback (most recent call last)
# <ipython-input-6-f3f62a95ec9e> in <module>()
#       1 #music = music21.corpus.parse('bach/bwv87.7.mxl')
#       2 music = music21.corpus.parse(paths[6])
# ----> 3 show(music)
#       4 play(music)
#
# <ipython-input-3-d71b438e1949> in show(music)
#       1 def show(music):
# ----> 2   display(Image(str(music.write('lily.png'))))
#       3
#       4 def play(music):
#       5   filename = music.write('mid')
#
# /usr/local/lib/python3.7/dist-packages/music21/stream/__init__.py in write(self, *args, **kwargs)
#     249         if self.isSorted is False and self.autoSort:
#     250             self.sort()
# --> 251         return super().write(*args, **kwargs)
#     252
#     253
#
# /usr/local/lib/python3.7/dist-packages/music21/base.py in write(self, fmt, fp, **keywords)
#    2504         scClass = common.findSubConverterForFormat(regularizedConverterFormat)
#    2505         formatWriter = scClass()
# -> 2506         return formatWriter.write(self, regularizedConverterFormat, fp, subformats, **keywords)
#    2507
#    2508
#
# /usr/local/lib/python3.7/dist-packages/music21/converter/subConverters.py in write(self, obj, fmt, fp, subformats, **keywords)
#     412     def write(self, obj, fmt, fp=None, subformats=None, **keywords):  # pragma: no cover
#     413         from music21 import lily
# --> 414         conv = lily.translate.LilypondConverter()
#     415         if 'coloredVariants' in keywords and keywords['coloredVariants'] is True:
#     416             conv.coloredVariants = True
#
# /usr/local/lib/python3.7/dist-packages/music21/lily/translate.py in __init__(self)
#     146     def __init__(self):
#     147         self.topLevelObject = lyo.LyLilypondTop()
# --> 148         self.setupTools()
#     149         self.context = self.topLevelObject
#     150         self.storedContexts = []
#
# /usr/local/lib/python3.7/dist-packages/music21/lily/translate.py in setupTools(self)
#     192             raise LilyTranslateException(
#     193                  "Cannot find a copy of Lilypond installed on your system. " +
# --> 194                  "Please be sure it is installed. And that your " +
#     195                  "environment.UserSettings()['lilypondPath'] is set to find it.")
#     196         stdout, unused = proc.communicate()
#
# LilyTranslateException: Cannot find a copy of Lilypond installed on your system. Please be sure it is installed. And that your environment.UserSettings()['lilypondPath'] is set to find it.

# %% [markdown]
# # Preprocess dataset
#
#
# ```
# https://github.com/musikalkemist/generating-melodies-with-rnn-lstm/blob/master/3%20-%20Preprocessing%20dataset%20for%20melody%20generation%20pt%201/code/preprocess.py
# ```

# %% [markdown]
# ## Raw preprocessing

# %%
# durations in quarter length
ACCEPTABLE_DURATIONS = [
    0.25, # 16th note
    0.5, # 8th note
    0.75,
    1.0, # quarter note
    1.5,
    2, # half note
    3,
    4 # whole note
]

SAVE_DIR = "./encoded_datasets/test_dataset/"
SINGLE_FILE_DATASET_OUTPUT = "./encoded_datasets/single_file_test_dataset.txt"
MAPPINGS_FILE = "./encoded_datasets/mappings.txt"
SEQUENCE_LENGTH = 64
SAVE_MODEL_PATH = "./encoded_datasets/model.h5"
OUTPUT_MIDI_PATH = "./encoded_datasets/"

# %%
def hasAcceptableDurations(song, acceptable_durations):
    for note in song.flat.notesAndRests:
        if note.duration.quarterLength not in acceptable_durations:
            return False
    return True

# %%
def transpose(song):
    # Estimate key using music21
    key = song.analyze("key")

    # Get interval for transposition
    if key.mode == "major":
        interval = music21.interval.Interval(key.tonic, music21.pitch.Pitch("C"))
    if key.mode == "minor":
        interval = music21.interval.Interval(key.tonic, music21.pitch.Pitch("A"))
    
    transposed_song = song.transpose(interval)
    return transposed_song

# %%
def encodeSong(song, time_step=0.25):
    encoded_song = []
    for event in song.flat.notesAndRests:
        # Handle notes
        if isinstance(event, music21.note.Note):
            symbol = event.pitch.midi
        # Handle rests
        elif isinstance(event, music21.note.Rest):
            symbol = "r"
        else:
            print(event)

        steps = int(event.duration.quarterLength/time_step)
        for step in range(steps):
            # If it's the first time we see a note/rest, we encode it.
            # Otherwise, it means we're carrying the same symbol a new time step
            if step == 0:
                encoded_song.append(symbol)
            else:
                encoded_song.append("_")

    # Cast encoded song to str
    encoded_song = " ".join(map(str, encoded_song))
    return encoded_song

# %%
def preprocess():
    # Load songs
    paths = music21.corpus.getComposer('bach')
    print("Loaded {} songs".format(len(paths)))

    paths = paths[0:50]

    for i, path in enumerate(paths):
        print('Processing song {}'.format(i))
        song = music21.corpus.parse(path)
        # Remove songs which have non acceptable durations
        if not hasAcceptableDurations(song, ACCEPTABLE_DURATIONS):
            print('- Not acceptable durations')
            continue
        
        # Transpose song to Cmaj/Amin
        #song = transpose(song)

        # Encode song
        encoded_song = encodeSong(song)
        
        # Save encoded song
        save_path = os.path.join(SAVE_DIR, str(i) + ".txt")
        with open(save_path, "w") as fp:
            fp.write(encoded_song)
            print('- Song saved')

# %%
preprocess()
# Out:
# Loaded 433 songs
# Processing song 0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-62eb8933cf6a> in <module>()
# ----> 1 preprocess()
#
# <ipython-input-11-22bcbd8be4dd> in preprocess()
#      22         # Save encoded song
#      23         save_path = os.path.join(SAVE_DIR, str(i) + ".txt")
# ---> 24         with open(save_path, "w") as fp:
#      25             fp.write(encoded_song)
#      26             print('- Song saved')
#
# FileNotFoundError: [Errno 2] No such file or directory: './encoded_datasets/test_dataset/0.txt'

# %% [markdown]
# ## Generate mappings

# %%
def load(file_path):
    with open(file_path, "r") as fp:
        song = fp.read()
    return song

# %%
def createSingleFileDataset(dataset_path, output_path, sequence_length):
    new_song_delimiter = "/ " * sequence_length
    dataset = ""

    # Load songs and add delimiters
    for encoded_song_filename in os.listdir(dataset_path):
        file_path = os.path.join(dataset_path, encoded_song_filename)
        song = load(file_path)
        dataset = dataset + song + " " + new_song_delimiter

    # Remove empty space at the end
    dataset = dataset[:-1]

    # Save our final single file dataset
    with open(output_path, "w") as fp:
        fp.write(dataset)

    return dataset

# %%
raw_dataset = createSingleFileDataset(SAVE_DIR, SINGLE_FILE_DATASET_OUTPUT, SEQUENCE_LENGTH)
len(raw_dataset)

# %%
def createMapping(raw_dataset, mapping_path):
    mappings = {}

    # Identify vocabulary
    raw_dataset = raw_dataset.split()
    vocabulary = list(set(raw_dataset))

    # Create mapping
    for i, symbol in enumerate(vocabulary):
        mappings[symbol] = i

    # Save vocabulary to a json file
    with open(mapping_path, "w") as fp:
        json.dump(mappings, fp, indent=4)

# %%
createMapping(raw_dataset, MAPPINGS_FILE)

# %% [markdown]
# ## Create sequences

# %%
def datasetToNumerical(raw_dataset, mappings_file):
    numerical_dataset = []

    # Load mappings
    with open(mappings_file, 'r') as fp:
        mappings = json.load(fp)
    
    raw_dataset = raw_dataset.split()

    # Map symbol to numerical value
    for symbol in raw_dataset:
        numerical_dataset.append(mappings[symbol])
    
    return numerical_dataset

# %%
numerical_dataset = datasetToNumerical(raw_dataset, MAPPINGS_FILE)

# %%
def generateTrainingSequence(numerical_dataset, seq_length):
    # One-hot encode the sequences
    vocabulary_size = len(set(numerical_dataset))
    ohe_numerical_dataset = tf.keras.utils.to_categorical(numerical_dataset, num_classes=vocabulary_size)

    X = []
    y = []

    # Generate training sequences
    num_sequences = len(ohe_numerical_dataset) - seq_length
    for i in range(num_sequences):
        X.append(ohe_numerical_dataset[i: i + seq_length])
        y.append(ohe_numerical_dataset[i + seq_length])

    # Inputs size: (# of sequences, sequence length, vocabulary size)
    X = np.array(X)
    y = np.array(y)

    return X, y

# %%
X, y = generateTrainingSequence(numerical_dataset, SEQUENCE_LENGTH)

# %% [markdown]
# # Training

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Bidirectional, Flatten

# %%
def buildModel(vocabulary_size):
    model = Sequential()
    model.add(LSTM(64, input_shape=(None, vocabulary_size), return_sequences=True))
    model.add(Dropout(0.3))
    model.add(Bidirectional(LSTM(64, return_sequences=False)))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation="relu"))
    model.add(Dense(vocabulary_size, activation="softmax"))

    model.compile(loss="categorical_crossentropy", 
                  optimizer="adam", 
                  metrics=['accuracy'])

    model.summary()

    return model

# %%
def train(X, y, epochs, save_model_path, model=None):
    vocabulary_size = len(y[0])
    if model == None:
        model = buildModel(vocabulary_size)

    model.fit(X, y, epochs=epochs, batch_size=32)
    model.save(save_model_path)

# %%
train(X, y, 10, SAVE_MODEL_PATH)

# %% [markdown]
# # Generate melody

# %%
model = tf.keras.models.load_model(SAVE_MODEL_PATH)

with open(MAPPINGS_FILE, "r") as fp:
    mappings = json.load(fp)

start_symbols = ["/"] * SEQUENCE_LENGTH

# %%
epochs = 50
train(X, y, epochs, SAVE_MODEL_PATH, model)

# %%
def sampleWithTemperature(probabilities, temperature):
    predictions = np.log(probabilities) / temperature
    probabilities = np.exp(predictions) / np.sum(np.exp(predictions))

    choices = range(len(probabilities)) # [0, 1, 2, 3]
    index = np.random.choice(choices, p=probabilities)

    return index

# %%
def generateMelody(seed, nb_steps, max_seq_length, temperature):
    np.random.seed(10)
    
    seed = seed.split()
    melody = seed
    seed = start_symbols + seed

    # Map seed to numerical values
    seed = [mappings[symbol] for symbol in seed]

    for _ in range(nb_steps):
        # Limit the seed to max_seq_length
        seed = seed[-max_seq_length:]

        # One-hot encode the seed
        ohe_seed = tf.keras.utils.to_categorical(seed, num_classes=len(mappings))
        ohe_seed = ohe_seed[np.newaxis, ...]

        # Predict the next note
        probabilities = model.predict(ohe_seed)[0] 

        # Sample from probabilities
        note = sampleWithTemperature(probabilities, temperature)

        # Update seed
        seed.append(note)

        output_symbol = [k for k, v in mappings.items() if v == note][0]

        # Check whether we are at the end of the melody
        if output_symbol == "/":
            break
        
        # Update melody
        melody.append(output_symbol)
    
    return melody

# %%
def saveMelody(melody, path, step_duration=0.25, format="midi", file_name="mel.mid"):
    # Create a music21 stream
    stream = music21.stream.Stream()

    start_symbol = None
    step_counter = 1

    # parse all the symbols in the melody and create note/rest objects
    for i, symbol in enumerate(melody):

        # handle case in which we have a note/rest
        if symbol != "_" or i + 1 == len(melody):

            # ensure we're dealing with note/rest beyond the first one
            if start_symbol is not None:

                quarter_length_duration = step_duration * step_counter # 0.25 * 4 = 1

                # handle rest
                if start_symbol == "r":
                    music21_event = music21.note.Rest(quarterLength=quarter_length_duration)

                # handle note
                else:
                    music21_event = music21.note.Note(int(start_symbol), quarterLength=quarter_length_duration)

                stream.append(music21_event)

                # reset the step counter
                step_counter = 1

            start_symbol = symbol

        # handle case in which we have a prolongation sign "_"
        else:
            step_counter += 1

    # write the music21 stream to a midi file
    stream.write(format, os.path.join(path, file_name))
    return stream

# %%
seed = "67 _ _ _ _ _ 65 _ 64 _ 62 _ 60 _ _ _"
#seed = "67 _ 67 _ 67 _ _ 65 64 _ 64 _ 64 _ _"


# Temperature : between 0 and 1
# 0 : uniform sampling from probabilities
# 1 : argmax
temperature = 0.6

melody = generateMelody(seed, 200, SEQUENCE_LENGTH, temperature)

# %%
final_melody = saveMelody(melody, OUTPUT_MIDI_PATH)
print(melody)

# %%
show(final_melody)
play(final_melody)

# %%
for k in range(50, 60):
    # Temperature : between 0 and 1
    # 0 : uniform sampling from probabilities
    # 1 : argmax
    seed = str(k)
    temperature = 0.4

    melody = generateMelody(seed, 200, SEQUENCE_LENGTH, temperature)

    final_melody = saveMelody(melody, OUTPUT_MIDI_PATH)
    print(melody)

    show(final_melody)
    play(final_melody)
